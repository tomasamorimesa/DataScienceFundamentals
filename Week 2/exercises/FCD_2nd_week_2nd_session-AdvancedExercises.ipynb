# %% [markdown]
# # 2nd Week - Introduction to Python (Advanced Exercises)

# %% [markdown]
# Welcome to the advanced Python coding problems! These are only for the skilled Python programmers!

# %% [markdown]
# ## 1. Consider the algorithm for ordering a list named “Bubble Sort”
# This algoritm goes through the list, to each element of the list, compares this element with the following one, and changes the order of the two elements if the first one is greater than the second one. This procedure is repeated until the list is completely ordered.

# %% [markdown]
# ![Buble Sort](https://favtutor.com/resources/images/uploads/mceu_61632030011682402256084.png)

# %% [markdown]
# 1.1 Create a table with random integers. Code the algorithm in Python, then run your program.

# %% [markdown]
# Insert your code here:

# %% [markdown]
# 1.2 Count the time spent by your code. Your code goes here:

# %% [markdown]
# 1.3 Now optimize your code with the Python swapping expression: "a, b = b, a"

# %% [markdown]
# Insert your code here:

# %% [markdown]
# 1.4 Again, count the time spent by your code. Which version is the fastest?

# %% [markdown]
# ## 2. Palindrome

# %% [markdown]
# 2.1 Code an algorithm that detects if a word or a phrase is a palindrome, and test it.

# %% [markdown]
# Examples of palindromes:

# %% [markdown]
# ![Palindrome](https://uselessetymology.files.wordpress.com/2019/10/palindrome-useless-etymology-12.png?w=1200)

# %% [markdown]
# Insert your code here:

# %% [markdown]
# 2.2 Are there palindromes in your mother language?

# %%
Give examples here:
