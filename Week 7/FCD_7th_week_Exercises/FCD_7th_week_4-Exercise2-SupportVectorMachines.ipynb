# %% [markdown]
# # Support Vector Machine Exercise - Classification Problem

# %% [markdown]
# This exercise allows studying the dataset ``iris`` and applying SVM for classification

# %% [markdown]
# <img height=100 width=200 align="left" src="https://user-images.githubusercontent.com/47174160/56137829-89e4a000-5f8d-11e9-9b9c-82aa58013d95.png" />

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
iris = load_iris()

# %% [markdown]
# #### 1. Explore the iris dataset (before converting into a DataFrame)
# HINT: Look for ``feature_names`` and ``target_names``

# %% [markdown]
# #### 2. Convert the iris dataset to a Pandas dataframe
# HINT: Use ``feature_names`` as columns of the dataframe

# %% [markdown]
# #### 3. Define the target column (or the output column) -
# Since this is a supervised classification problem, we need to define an output variable
#
# HINT: Use ``target`` from the iris dataset

# %% [markdown]
# #### 4. Filter the dataset in order to choose only the Setosa and Versicolor species.
# HINT: Check the result from ``iris.target_names`` vs. ``iris.target``. Filter 'setosa', then filter 'versicolor', then concatenate both.

# %% [markdown]
# #### 5. Add a new column named ``flower_name`` which will be the flower names (species) - Solved
# HINT: Use ``target_names`` and ``target``

# %%
df_iris['flower_name'] =df_iris.target.apply(lambda x: iris.target_names[x])
df_iris.head()
df_iris.tail()

# %% [markdown]
# #### 6. Create new Dataframes for each species
# HINT: Use ``flower_name`` column to filter

# %%
# for setosa

# %%
# for versicolor

# %%
# for virginica

# %% [markdown]
# #### 7. Use scatter plots to plot Sepal and Petal lenghts vs. Sepal and Petal witdths for each the following species

# %% [markdown]
# **Sepal length vs Sepal Width (Setosa vs Versicolor) - Solved**

# %%
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.scatter(df_iris_setosa['sepal length (cm)'], df_iris_setosa['sepal width (cm)'],color="green",marker='+')
plt.scatter(df_iris_versicolor['sepal length (cm)'], df_iris_versicolor['sepal width (cm)'],color="blue",marker='.')

# %% [markdown]
# **Petal length vs Petal Width (Setosa vs Versicolor)**

# %% [markdown]
# **Sepal length vs Sepal Width (Versicolor vs Virginica)**

# %% [markdown]
# **Petal length vs Petal Width (Versicolor vs Virginica)**

# %% [markdown]
# #### 8. Train Using Support Vector Machine (SVM)
# a) Create a train and test datasets

# %% [markdown]
# #### 9. Use the method ``train_test_split`` to split train / test sizes. Use 20% for the test size)
#
# HINT: Use ``test_size`` parameter of the ``train_test_split`` method to define the test size (ranges from 0 to 1)

# %% [markdown]
# #### 10. Print the lenght of both training and test sets

# %% [markdown]
# #### 11. Train the SVM using the sets created before. Test different kernels.

# %% [markdown]
# #### 12. Evaluate the performance. Create a confusion matrix.
# HINT: Use the ``X_test``.

# %% [markdown]
# #### 13. Print a classfication report.
# HINT: Use the ``classification_report`` method.

# %% [markdown]
# #### 14. Print the mean accuracy for all the labels
# HINT: You can use the ``score`` method.
