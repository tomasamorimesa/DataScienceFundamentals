# %% [markdown]
# #### 15. Train a SVM classifier using digits dataset (i.e. from sklearn.datasets import load_digits):
#
# 1. Evaluate the performance of your model SVM's different kernels (rbf and linear).
# 2. Fine-tune your model further using regularization (C) and gamma parameters achieve highesr accurancy scores.
# 3. Define various training data sizes and see if there's any difference.
#
# Use the cell (and create more) below at will:
